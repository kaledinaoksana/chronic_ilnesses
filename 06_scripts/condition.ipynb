# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Preparation

# %%
# loading
def load_csv(filename):
    # file_loc = 'files/'+filename+'.csv'
    file_loc = filename
    data = pd.read_csv(file_loc, low_memory=False)
    return data

# create count table
def calculate_count_table(df,column_name):
    counts = df[column_name].value_counts().reset_index()
    counts.columns = [column_name, 'count']
    
    counts = counts.sort_values(by='count')
    return counts

def calculate_count_table_with_null(df,column_name):
    counts = df[column_name].value_counts().reset_index()
    counts.columns = [column_name, 'count']
    counts = counts.sort_values(by='count')
    
    null_count = df[column_name].isnull().sum()
    null_row = pd.DataFrame({column_name: ['null'], 'count': [null_count]})
    counts = pd.concat([counts, null_row], ignore_index=True)
    
    return counts

# %% [markdown]
# ### Code

# %%
filename="export.csv"

raw_data = load_csv(filename)
df = raw_data.copy() 
users=df.drop(columns=['trackable_id','trackable_type','trackable_name','trackable_value','checkin_date']).copy().drop_duplicates()

# %%
df
# Out:
#                                   user_id   age     sex country checkin_date  \
# 0        QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1        QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0    male      US   2015-11-26
# 2        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 3        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 4        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# ...                                   ...   ...     ...     ...          ...
# 7976218  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976219  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976220  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976221  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976222  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
#
#         trackable_id trackable_type  \
# 0               1069      Condition
# 1               1069      Condition
# 2               3168      Condition
# 3               3169      Condition
# 4               3170      Condition
# ...              ...            ...
# 7976218            1            Tag
# 7976219            2            Tag
# 7976220         9002           Food
# 7976221         9139           Food
# 7976222        10260           Food
#
#                                             trackable_name trackable_value
# 0                                       Ulcerative colitis               0
# 1                                       Ulcerative colitis               0
# 2        pain in left upper arm felt like i was getting...               4
# 3                                  hip pain when gettin up               3
# 4                                      pain in hand joints               4
# ...                                                    ...             ...
# 7976218                                              tired             NaN
# 7976219                                           stressed             NaN
# 7976220                                               soup             NaN
# 7976221                                             yogurt             NaN
# 7976222                                            granola             NaN
#
# [7976223 rows x 9 columns]

# %% [markdown]
# ## Symptom

# %%
df_symptoms = df.loc[(df['trackable_type']=="Symptom")]

# %%
pd.DataFrame(df_symptoms)
# Out:
#                                   user_id   age     sex country checkin_date  \
# 15       QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 24       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-26
# 31       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-27
# 32       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-27
# 33       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-27
# ...                                   ...   ...     ...     ...          ...
# 7976213  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976214  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976215  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976216  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976217  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
#
#         trackable_id trackable_type         trackable_name trackable_value
# 15               123        Symptom        Joint stiffness               3
# 24               152        Symptom                 Nausea               1
# 31               152        Symptom                 Nausea               2
# 32                 8        Symptom                Anxiety               2
# 33               242        Symptom                Fatigue               1
# ...              ...            ...                    ...             ...
# 7976213         3368        Symptom  difficulty getting up               4
# 7976214          153        Symptom              Neck pain               2
# 7976215          242        Symptom                Fatigue               3
# 7976216         1026        Symptom     Poor concentration               3
# 7976217        30924        Symptom      poor productivity               3
#
# [3642279 rows x 9 columns]

# %%
import emoji
import re
from nltk.corpus import stopwords
import string
import unicodedata
import contractions
import inflect
from nltk.tokenize import word_tokenize


def emojis_words(text):
    # Модуль emoji: преобразование эмоджи в их словесные описания
    clean_text = emoji.demojize(text, delimiters=(" ", " "))
    # Редактирование текста путём замены ":" и" _", а так же - путём добавления пробела между отдельными словами
    clean_text = clean_text.replace(":", "").replace("_", " ")
    return clean_text

def clean_text(input_text):    
    
    # HTML-теги: первый шаг - удалить из входного текста все HTML-теги
    clean_text = re.sub('<[^<]+?>', '', input_text)
    
    # URL и ссылки: далее - удаляем из текста все URL и ссылки
    clean_text = re.sub(r'http\S+', '', clean_text)

    # Эмоджи и эмотиконы: используем собственную функцию для преобразования эмоджи в текст
    # Важно понимать эмоциональную окраску обрабатываемого текста
    clean_text = emojis_words(clean_text)
    
    # Приводим все входные данные к нижнему регистру
    clean_text = clean_text.lower()

    # Убираем все пробелы
    # Так как все данные теперь представлены словами - удалим пробелы
    clean_text = re.sub('\s+', ' ', clean_text)

    # Преобразование символов с диакритическими знаками к ASCII-символам: используем функцию normalize из модуля unicodedata и преобразуем символы с диакритическими знаками к ASCII-символам
    clean_text = unicodedata.normalize('NFKD', clean_text).encode('ascii', 'ignore').decode('utf-8', 'ignore')

    # Разворачиваем сокращения: текст часто содержит конструкции вроде "don't" или "won't", поэтому развернём подобные сокращения
    clean_text = contractions.fix(clean_text)

    # Убираем специальные символы: избавляемся от всего, что не является "словами"
    clean_text = re.sub('[^a-zA-Z0-9\s]', '', clean_text)

    # Записываем числа прописью: 100 превращается в "сто" (для компьютера)
    temp = inflect.engine()
    words = []
    for word in clean_text.split():
        if word.isdigit():
            words.append(temp.number_to_words(word))
        else:
            words.append(word)
    clean_text = ' '.join(words)

    # Стоп-слова: удаление стоп-слов - это стандартная практика очистки текстов
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(clean_text)
    tokens = [token for token in tokens if token not in stop_words]
    clean_text = ' '.join(tokens)

    # Знаки препинания: далее - удаляем из текста все знаки препинания
    clean_text = re.sub(r'[^\w\s]', '', clean_text)

    # И наконец - возвращаем очищенный текст
    return clean_text

# %%
# df_symptoms['trackable_name'] = df_symptoms['trackable_name'].apply(clean_text)

# %%
symptom_table_count = calculate_count_table(df_symptoms,"trackable_name")
df_sy = symptom_table_count.sort_values(by='count', ascending=False).head(30)
df_sy.rename(columns={'trackable_name': 'symptom', 'count': 'symptom count'}, inplace=True)

# %%
df_symptoms.to_csv('df_symptoms.csv', encoding='utf-8')

# %% [markdown]
# ### Condition

# %%
df_condition = df.loc[(df['trackable_type']=="Condition")]
df_condition
# Out:
#                                   user_id   age     sex country checkin_date  \
# 0        QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1        QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0    male      US   2015-11-26
# 2        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 3        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 4        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# ...                                   ...   ...     ...     ...          ...
# 7976184  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-12-04
# 7976206  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976207  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976208  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976209  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
#
#         trackable_id trackable_type  \
# 0               1069      Condition
# 1               1069      Condition
# 2               3168      Condition
# 3               3169      Condition
# 4               3170      Condition
# ...              ...            ...
# 7976184            7      Condition
# 7976206         2075      Condition
# 7976207           64      Condition
# 7976208          291      Condition
# 7976209         1131      Condition
#
#                                             trackable_name trackable_value
# 0                                       Ulcerative colitis               0
# 1                                       Ulcerative colitis               0
# 2        pain in left upper arm felt like i was getting...               4
# 3                                  hip pain when gettin up               3
# 4                                      pain in hand joints               4
# ...                                                    ...             ...
# 7976184                                          Achalasia               3
# 7976206                                        Period pain               1
# 7976207                                            Anxiety               3
# 7976208                                         Depression               2
# 7976209                                  Chronic Migraines               2
#
# [1111517 rows x 9 columns]

# %%
df_condition['trackable_name'] = df_condition['trackable_name'].apply(clean_text)
df_condition.to_csv('df_condition.csv', encoding='utf-8')
df_condition
# Out:
# <ipython-input-51-34c88cdd61d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_condition['trackable_name'] = df_condition['trackable_name'].apply(clean_text)
#                                   user_id   age     sex country checkin_date  \
# 0        QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1        QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0    male      US   2015-11-26
# 2        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 3        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 4        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# ...                                   ...   ...     ...     ...          ...
# 7976184  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-12-04
# 7976206  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976207  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976208  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976209  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
#
#         trackable_id trackable_type  \
# 0               1069      Condition
# 1               1069      Condition
# 2               3168      Condition
# 3               3169      Condition
# 4               3170      Condition
# ...              ...            ...
# 7976184            7      Condition
# 7976206         2075      Condition
# 7976207           64      Condition
# 7976208          291      Condition
# 7976209         1131      Condition
#
#                                      trackable_name trackable_value
# 0                                ulcerative colitis               0
# 1                                ulcerative colitis               0
# 2        pain left upper arm felt like getting shot               4
# 3                                   hip pain gettin               3
# 4                                  pain hand joints               4
# ...                                             ...             ...
# 7976184                                   achalasia               3
# 7976206                                 period pain               1
# 7976207                                     anxiety               3
# 7976208                                  depression               2
# 7976209                           chronic migraines               2
#
# [1111517 rows x 9 columns]

# %%
condition_table_count = calculate_count_table(df_condition,"trackable_name")
df_co = condition_table_count.sort_values(by='count', ascending=False).head(30)
df_co.rename(columns={'trackable_name': 'condition', 'count': 'condition count'}, inplace=True)

# %% [markdown]
# ### Treatment

# %%
df_treatment = df.loc[(df['trackable_type']=="Treatment")]
df_treatment
# Out:
#                                   user_id   age     sex country checkin_date  \
# 25       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-26
# 34       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-27
# 35       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-27
# 201      QEVuQwEA08uRNqb7wltBMKWvJGIUwA==  37.0  female      US   2015-05-26
# 202      QEVuQwEA08uRNqb7wltBMKWvJGIUwA==  37.0  female      US   2015-05-26
# ...                                   ...   ...     ...     ...          ...
# 7976180  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-10-03
# 7976181  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-10-13
# 7976182  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-10-21
# 7976196  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-12-04
# 7976205  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-12-03
#
#         trackable_id trackable_type trackable_name trackable_value
# 25              9890      Treatment         Zofran          8.0 mg
# 34              9890      Treatment         Zofran          4.0 mg
# 35              4934      Treatment       Klonopin          0.5 mg
# 201             1470      Treatment       Caffeine        100.0 mg
# 202             5681      Treatment      Methadone         20.0 mg
# ...              ...            ...            ...             ...
# 7976180         9951      Treatment     Mesalazine              1g
# 7976181         9951      Treatment     Mesalazine              1g
# 7976182         9951      Treatment     Mesalazine              1g
# 7976196         9951      Treatment     Mesalazine              1g
# 7976205         9951      Treatment     Mesalazine              1g
#
# [901820 rows x 9 columns]

# %%
df_treatment['trackable_name'] = df_treatment['trackable_name'].apply(clean_text)
df_treatment.to_csv('df_treatment.csv', encoding='utf-8')
df_treatment
# Out:
# <ipython-input-53-ae2cbc620fdd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_treatment['trackable_name'] = df_treatment['trackable_name'].apply(clean_text)
#                                   user_id   age     sex country checkin_date  \
# 25       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-26
# 34       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-27
# 35       QEVuQwEAO+R1md5HUn8+w1Qpbg7ogw==   NaN     NaN     NaN   2015-05-27
# 201      QEVuQwEA08uRNqb7wltBMKWvJGIUwA==  37.0  female      US   2015-05-26
# 202      QEVuQwEA08uRNqb7wltBMKWvJGIUwA==  37.0  female      US   2015-05-26
# ...                                   ...   ...     ...     ...          ...
# 7976180  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-10-03
# 7976181  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-10-13
# 7976182  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-10-21
# 7976196  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-12-04
# 7976205  QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==  48.0    male      GB   2019-12-03
#
#         trackable_id trackable_type trackable_name trackable_value
# 25              9890      Treatment         zofran          8.0 mg
# 34              9890      Treatment         zofran          4.0 mg
# 35              4934      Treatment       klonopin          0.5 mg
# 201             1470      Treatment       caffeine        100.0 mg
# 202             5681      Treatment      methadone         20.0 mg
# ...              ...            ...            ...             ...
# 7976180         9951      Treatment     mesalazine              1g
# 7976181         9951      Treatment     mesalazine              1g
# 7976182         9951      Treatment     mesalazine              1g
# 7976196         9951      Treatment     mesalazine              1g
# 7976205         9951      Treatment     mesalazine              1g
#
# [901820 rows x 9 columns]

# %%
treatment_table_count = calculate_count_table(df_treatment,"trackable_name")
df_tr = treatment_table_count.sort_values(by='count', ascending=False).head(30)
df_tr.rename(columns={'trackable_name': 'treatment', 'count': 'treatment count'}, inplace=True)

# %%
merged_df = pd.concat([df_tr, df_sy, df_co], axis=1)
merged_df
# Out:
#         treatment  treatment count            symptom  symptom count  \
# 0       ibuprofen            21485           headache         108719
# 1       magnesium            11424            fatigue         107800
# 2      vitamin d3            11379             nausea          89624
# 3     paracetamol            11253          brain fog          73226
# 4         vitamin            10577         joint pain          65443
# 5      gabapentin             9627  fatigue tiredness          63395
# 6        tramadol             9284            anxiety          61610
# 7      prednisone             8309           diarrhea          52425
# 8        naproxen             8211          dizziness          50162
# 9    multivitamin             7925         depression          43485
# 10     omeprazole             7552       constipation          40895
# 11      probiotic             6824          back pain          37857
# 12  amitriptyline             6777          neck pain          37769
# 13      plaquenil             6666     abdominal pain          33361
# 14        tylenol             6355           migraine          32135
# 15       cymbalta             6085        muscle pain          30214
# 16  levothyroxine             5865    lower back pain          29194
# 17      melatonin             5535       stomach pain          27220
# 18     sertraline             5325           insomnia          26840
# 19         zyrtec             4743           bloating          24004
# 20      vitamin c             4644         chest pain          22794
# 21    vitamin b12             4580           hip pain          20767
# 22           yoga             4532        sore throat          18950
# 23       exercise             4142   shortness breath          18522
# 24     folic acid             4065          knee pain          17714
# 25          sleep             3994      shoulder pain          17598
# 26     meditation             3976       chronic pain          16885
# 27     ranitidine             3766       irritability          16366
# 28       benadryl             3682    muscle weakness          14610
# 29      midodrine             3613    lightheadedness          13944
#
#                                     condition  condition count
# 0                                fibromyalgia            55447
# 1                                  depression            50122
# 2                                     anxiety            46968
# 3                    chronic fatigue syndrome            28262
# 4                                    migraine            26116
# 5                                         ibs            17328
# 6                                     fatigue            14920
# 7                                      asthma            14219
# 8                               endometriosis            13907
# 9                       ehlersdanlos syndrome            13679
# 10                   irritable bowel syndrome            11801
# 11                                  headaches            11363
# 12               generalized anxiety disorder            10275
# 13                          chronic migraines            10034
# 14                                 joint pain             9789
# 15                                       pots             9010
# 16                                  allergies             8722
# 17                               chronic pain             8368
# 18                                   insomnia             7784
# 19                       rheumatoid arthritis             7243
# 20                                  back pain             7116
# 21                               lyme disease             6921
# 22                               dysautonomia             6835
# 23                             crohns disease             6768
# 24  postural orthostatic tachycardia syndrome             6742
# 25                    chronic daily headaches             6323
# 26                             hypothyroidism             6317
# 27                  myalgic encephalomyelitis             6259
# 28                         ulcerative colitis             5930
# 29                                     nausea             5813
